# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya2915/image-to-pencilsketch/blob/main/photo_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread('babygirl.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=545x640 at 0x7FBD2C9A00D0>

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=545x640 at 0x7FBD2C8AC890>

# %%
inverted_image = 255-gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=545x640 at 0x7FBD2B843990>

# %%
blurred = cv2.GaussianBlur(inverted_image,(5,5),0)

# %%
inverted_blurred = 255-blurred
pencil_sketch=cv2.divide(gray_image, blurred, scale=256)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=545x640 at 0x7FBD27087690>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=545x640 at 0x7FBD26FA69D0>
# <PIL.Image.Image image mode=L size=545x640 at 0x7FBD2701D3D0>
